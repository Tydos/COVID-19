# %%
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv('D:/GitHub/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-01-2021.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(10)
# Out:
#    FIPS Admin2                Province_State       Country_Region  \
# 0   NaN    NaN                           NaN          Afghanistan
# 1   NaN    NaN                           NaN              Albania
# 2   NaN    NaN                           NaN              Algeria
# 3   NaN    NaN                           NaN              Andorra
# 4   NaN    NaN                           NaN               Angola
# 5   NaN    NaN                           NaN  Antigua and Barbuda
# 6   NaN    NaN                           NaN            Argentina
# 7   NaN    NaN                           NaN              Armenia
# 8   NaN    NaN  Australian Capital Territory            Australia
# 9   NaN    NaN               New South Wales            Australia
#
#            Last_Update       Lat       Long_  Confirmed  Deaths  Recovered  \
# 0  2021-01-02 05:22:33  33.93911   67.709953      52513    2201      41727
# 1  2021-01-02 05:22:33  41.15330   20.168300      58316    1181      33634
# ...

# %%
data.set_index('Country_Region', inplace=True)

# %%
data.head(10)
# Out:
#                      FIPS Admin2                Province_State  \
# Country_Region
# Afghanistan           NaN    NaN                           NaN
# Albania               NaN    NaN                           NaN
# Algeria               NaN    NaN                           NaN
# Andorra               NaN    NaN                           NaN
# Angola                NaN    NaN                           NaN
# Antigua and Barbuda   NaN    NaN                           NaN
# Argentina             NaN    NaN                           NaN
# Armenia               NaN    NaN                           NaN
# Australia             NaN    NaN  Australian Capital Territory
# Australia             NaN    NaN               New South Wales
#
#                              Last_Update       Lat       Long_  Confirmed  \
# Country_Region
# Afghanistan          2021-01-02 05:22:33  33.93911   67.709953      52513
# Albania              2021-01-02 05:22:33  41.15330   20.168300      58316
# ...

# %%
data.Active
# Out:
# Country_Region
# Afghanistan        8585
# Albania           23501
# Algeria           29740
# Andorra             570
# Angola             6017
#                   ...
# Ukraine               0
# Nauru                 0
# New Zealand           0
# Tuvalu                0
# United Kingdom        0
# Name: Active, Length: 4011, dtype: int64

# %%
data.describe()
# Out:
#                FIPS          Lat        Long_     Confirmed        Deaths  \
# count   3265.000000  3922.000000  3922.000000  4.011000e+03   4011.000000
# mean   32386.688208    35.768908   -71.113714  2.103663e+04    476.763650
# std    18017.294540    13.391261    55.220345  1.055323e+05   2833.345436
# min       66.000000   -71.949900  -175.198200  0.000000e+00      0.000000
# 25%    19049.000000    33.202974   -96.580090  7.010000e+02      9.000000
# 50%    30067.000000    37.910342   -86.708116  1.968000e+03     31.000000
# 75%    47039.000000    42.181730   -77.358102  7.693500e+03    112.000000
# max    99999.000000    71.706900   178.065000  2.636045e+06  81593.000000
#
#           Recovered        Active  Incident_Rate  Case_Fatality_Ratio
# count  4.011000e+03  4.011000e+03    3922.000000          3963.000000
# mean   1.180731e+04  9.259591e+03    5738.940929             2.228699
# std    8.193885e+04  5.719777e+04    3227.374130            17.174874
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4011 entries, Afghanistan to United Kingdom
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FIPS                 3265 non-null   float64
#  1   Admin2               3270 non-null   object
#  2   Province_State       3833 non-null   object
#  3   Last_Update          4011 non-null   object
#  4   Lat                  3922 non-null   float64
#  5   Long_                3922 non-null   float64
#  6   Confirmed            4011 non-null   int64
#  7   Deaths               4011 non-null   int64
#  8   Recovered            4011 non-null   int64
#  9   Active               4011 non-null   int64
#  10  Combined_Key         4011 non-null   object
#  11  Incident_Rate        3922 non-null   float64
#  12  Case_Fatality_Ratio  3963 non-null   float64
# dtypes: float64(5), int64(4), object(4)
# memory usage: 567.7+ KB

# %%
data.shape
# Out:
# (4011, 13)

# %%
data.columns
# Out:
# Index(['FIPS', 'Admin2', 'Province_State', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'Combined_Key',
#        'Incident_Rate', 'Case_Fatality_Ratio'],
#       dtype='object')

# %%
data.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia', 'Australia',
#        ...
#        'Winter Olympics 2022', 'Antarctica', 'United Kingdom',
#        'United Kingdom', 'Korea, North', 'Ukraine', 'Nauru', 'New Zealand',
#        'Tuvalu', 'United Kingdom'],
#       dtype='object', name='Country_Region', length=4011)

# %%
data.sort_values(by=['Deaths'], ascending=False)
# Out:
#                    FIPS      Admin2    Province_State          Last_Update  \
# Country_Region
# United Kingdom      NaN         NaN           England  2021-01-02 05:22:33
# France              NaN         NaN               NaN  2021-01-02 05:22:33
# Iran                NaN         NaN               NaN  2021-01-02 05:22:33
# India               NaN         NaN       Maharashtra  2021-01-02 05:22:33
# Brazil              NaN         NaN         Sao Paulo  2021-01-02 05:22:33
# ...                 ...         ...               ...                  ...
# US              90042.0  Unassigned      Pennsylvania  2021-01-02 05:22:33
# US              72001.0    Adjuntas       Puerto Rico  2021-01-02 05:22:33
# US              72003.0      Aguada       Puerto Rico  2021-01-02 05:22:33
# US              72005.0   Aguadilla       Puerto Rico  2021-01-02 05:22:33
# United Kingdom      NaN         NaN  Pitcairn Islands  2021-01-02 05:22:33
#
# ...

# %%
india = data.loc['India']
brazil = data.loc['Brazil']

# %%
india.head()
# Out:
#                 FIPS Admin2               Province_State          Last_Update  \
# Country_Region
# India            NaN    NaN  Andaman and Nicobar Islands  2021-01-02 05:22:33
# India            NaN    NaN               Andhra Pradesh  2021-01-02 05:22:33
# India            NaN    NaN            Arunachal Pradesh  2021-01-02 05:22:33
# India            NaN    NaN                        Assam  2021-01-02 05:22:33
# India            NaN    NaN                        Bihar  2021-01-02 05:22:33
#
#                       Lat      Long_  Confirmed  Deaths  Recovered  Active  \
# Country_Region
# India           11.225999  92.968178       4946      62       4826      58
# India           15.912900  79.740000     882612    7108     871916    3588
# India           27.768456  96.384277      16719      56      16564      99
# India           26.357149  92.830441     216251    1049     211910    3292
# India           25.679658  85.604840     252219    1400     245476    5343
#
# ...

# %%
brazil.head()
# Out:
#                 FIPS Admin2 Province_State          Last_Update      Lat  \
# Country_Region
# Brazil           NaN    NaN           Acre  2021-01-02 05:22:33  -9.0238
# Brazil           NaN    NaN        Alagoas  2021-01-02 05:22:33  -9.5713
# Brazil           NaN    NaN          Amapa  2021-01-02 05:22:33   0.9020
# Brazil           NaN    NaN       Amazonas  2021-01-02 05:22:33  -3.4168
# Brazil           NaN    NaN          Bahia  2021-01-02 05:22:33 -12.5797
#
#                   Long_  Confirmed  Deaths  Recovered  Active  \
# Country_Region
# Brazil         -70.8120      41689     796      33670    7223
# Brazil         -36.7820     105091    2496      99710    2885
# Brazil         -52.0030      68361     926      52670   14765
# Brazil         -65.8561     201574    5295     170178   26101
# Brazil         -41.7007     494684    9159     478198    7327
#
#                     Combined_Key  Incident_Rate  Case_Fatality_Ratio
# Country_Region
# ...

# %%
india_summary = india.head(5)

# %%
india_summary.shape
# Out:
# (5, 13)

# %%
india_summary.describe()
# Out:
#        FIPS        Lat      Long_      Confirmed       Deaths      Recovered  \
# count   0.0   5.000000   5.000000       5.000000     5.000000       5.000000
# mean    NaN  21.388832  89.505547  274549.400000  1935.000000  270138.400000
# std     NaN   7.366545   6.725754  358050.270277  2952.537891  353845.201441
# min     NaN  11.225999  79.740000    4946.000000    56.000000    4826.000000
# 25%     NaN  15.912900  85.604840   16719.000000    62.000000   16564.000000
# 50%     NaN  25.679658  92.830441  216251.000000  1049.000000  211910.000000
# 75%     NaN  26.357149  92.968178  252219.000000  1400.000000  245476.000000
# max     NaN  27.768456  96.384277  882612.000000  7108.000000  871916.000000
#
#             Active  Incident_Rate  Case_Fatality_Ratio
# count     5.000000       5.000000             5.000000
# mean   2476.000000     939.480771             0.686796
# std    2324.808702     551.716394             0.359543
# ...

# %%
india.columns
# Out:
# Index(['FIPS', 'Admin2', 'Province_State', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'Combined_Key',
#        'Incident_Rate', 'Case_Fatality_Ratio'],
#       dtype='object')

# %%
Assam = india.loc['Province_State'] == 'Assam'

# %%
Assam.describe()
# Out:
# count        13
# unique        1
# top       False
# freq         13
# Name: Province_State, dtype: object

# %%
Assam.shape
# Out:
# (13,)
